# %% [markdown]
# <a href="https://colab.research.google.com/github/tamaravera14/SIMULACI-N-I/blob/main/Parabola.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# Definir la función de la parábola
def parabola(x):
  return x**2

# Crear los valores de x
x = np.linspace(-5, 5, 400)

# Calcular los valores de y usando la función de la parábola
y = parabola(x)


# Crear la gráfica
plt.plot(x, y)

# Añadir etiquetas y título
plt.xlabel("x")
plt.ylabel("y")
plt.title("Gráfica de una Parábola")

# Mostrar la gráfica
plt.grid(True)
plt.show()
